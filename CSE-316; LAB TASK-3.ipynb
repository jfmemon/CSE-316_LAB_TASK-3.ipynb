# %%
data = []
choice = 'random'

def line():
  print('---------------------')

def show_menu():
  line()
  print('MENU')
  line()
  print('1. Add semester')
  print('2. Add courses')
  print('3. View courses')
  print('4. Select any courses you want unenroll from!')
  print('5. Exit!')
  line()
  choice = input('Enter your choice: ')
  return choice

while choice != '5':
  choice = show_menu()
  if choice == '1':
    item = input('Please add your own semester! ')
    data.append(item)
    print('Semester',item,'added.')
  elif choice == '2':
    item = input('Please add your semester courses! ')
    data.append(item)
    print('Courses',item,'added.')
  elif choice == '3':
    print('List of courses: ')
    for item in data:
      print(item)
  elif choice == '4':
    item = input('Which course you want to unenroll from? : ')
    if item in data:
      data.remove(item)
      print('Unenrolled courses: ',item)
    else:
      print('Could not find courses!',item)
  elif choice == '5':
    print('Goodbye! Have a good day!')
  else:
    print('Please enter one of 1, 2, 3, 4, 5.')
# Out:
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 1
# Please add your own semester! 7th
# Semester 7th added.
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 2
# Please add your semester courses! CSE-311
# Courses CSE-311 added.
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 2
# Please add your semester courses! CSE-312
# Courses CSE-312 added.
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 2
# Please add your semester courses! CSE-313
# Courses CSE-313 added.
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 2
# Please add your semester courses! CSE-314
# Courses CSE-314 added.
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 2
# Please add your semester courses! CSE-315
# Courses CSE-315 added.
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 2
# Please add your semester courses! CSE-316
# Courses CSE-316 added.
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 3
# List of courses:
# 7th
# CSE-311
# CSE-312
# CSE-313
# CSE-314
# CSE-315
# CSE-316
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 4
# Which course you want to unenroll from? : CSE-311
# Unenrolled courses:  CSE-311
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 3
# List of courses:
# 7th
# CSE-312
# CSE-313
# CSE-314
# CSE-315
# CSE-316
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 6
# Please enter one of 1, 2, 3, 4, 5.
# ---------------------
# MENU
# ---------------------
# 1. Add semester
# 2. Add courses
# 3. View courses
# 4. Select any courses you want unenroll from!
# 5. Exit!
# ---------------------
# Enter your choice: 5
# Goodbye! Have a good day!
